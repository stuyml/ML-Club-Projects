# %% [markdown]
# <a href="https://colab.research.google.com/github/stuyml/ML-Club-Projects/blob/master/Taxi_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Enter the ID of the Google Drive folder containing train.csv and test.csv files.
# The ID of the folder is the long string of numbers and letters in the URL of the folder in Google Drive.

file_list = drive.ListFile({'q': "'1bXgGh5zrfFishI5NUSM3Zfgrbb5A9Uzj' in parents and trashed=false"}).GetList()
for file1 in file_list:
  print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: Taxi Prediction.ipynb, id: 1nZ7shjZNEYe53kkkYs3QQnpUlzhQOZR4
# title: TFRecord file creator.ipynb, id: 1B2imMvxMaB1n9IUWH1GOXG-hS1ER6js8
# title: train.csv, id: 174cLWlxIEwb7VFqYfcVFuH1j-uaqLuPF
# title: GCP-Coupons-Instructions.rtf, id: 1kDN_kC5-GdO3CmN28_DEwWPFDHS-UlJM
# title: sample_submission.csv, id: 1k4RmIgAQO4XujlEp5nuZWlCNvCkrcK4p
# title: test.csv, id: 1pdLyx3edlI7WCBPFqurIIvO5IKzuxhEf

# %%
# Enter the ID of train.csv and test.csv. The IDs are printed in the output of the cell above.
train_downloaded = drive.CreateFile({'id': '174cLWlxIEwb7VFqYfcVFuH1j-uaqLuPF'})
train_downloaded.GetContentFile('train.csv')
test_downloaded = drive.CreateFile({'id': '1pdLyx3edlI7WCBPFqurIIvO5IKzuxhEf'})
test_downloaded.GetContentFile('test.csv')

# %%
# See the top rows of the train.csv file
# !ls
# !head train.csv
# !head test.csv
#!wc -l train.csv
# Out:
# adc.json  sample_data  test.csv  train.csv
# key,fare_amount,pickup_datetime,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude,passenger_count
# 2009-06-15 17:26:21.0000001,4.5,2009-06-15 17:26:21 UTC,-73.844311,40.721319,-73.84161,40.712278,1
# 2010-01-05 16:52:16.0000002,16.9,2010-01-05 16:52:16 UTC,-74.016048,40.711303,-73.979268,40.782004,1
# 2011-08-18 00:35:00.00000049,5.7,2011-08-18 00:35:00 UTC,-73.982738,40.76127,-73.991242,40.750562,2
# 2012-04-21 04:30:42.0000001,7.7,2012-04-21 04:30:42 UTC,-73.98713,40.733143,-73.991567,40.758092,1
# 2010-03-09 07:51:00.000000135,5.3,2010-03-09 07:51:00 UTC,-73.968095,40.768008,-73.956655,40.783762,1
# 2011-01-06 09:50:45.0000002,12.1,2011-01-06 09:50:45 UTC,-74.000964,40.73163,-73.972892,40.758233,1
# 2012-11-20 20:35:00.0000001,7.5,2012-11-20 20:35:00 UTC,-73.980002,40.751662,-73.973802,40.764842,1
# 2012-01-04 17:22:00.00000081,16.5,2012-01-04 17:22:00 UTC,-73.9513,40.774138,-73.990095,40.751048,1
# 2012-12-03 13:10:00.000000125,9,2012-12-03 13:10:00 UTC,-74.006462,40.726713,-73.993078,40.731628,1
# key,pickup_datetime,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude,passenger_count
# 2015-01-27 13:08:24.0000002,2015-01-27 13:08:24 UTC,-73.973320007324219,40.7638053894043,-73.981430053710938,40.74383544921875,1
# 2015-01-27 13:08:24.0000003,2015-01-27 13:08:24 UTC,-73.986862182617188,40.719383239746094,-73.998886108398438,40.739200592041016,1
# 2011-10-08 11:53:44.0000002,2011-10-08 11:53:44 UTC,-73.982524,40.75126,-73.979654,40.746139,1
# 2012-12-01 21:12:12.0000002,2012-12-01 21:12:12 UTC,-73.98116,40.767807,-73.990448,40.751635,1
# 2012-12-01 21:12:12.0000003,2012-12-01 21:12:12 UTC,-73.966046,40.789775,-73.988565,40.744427,1
# 2012-12-01 21:12:12.0000005,2012-12-01 21:12:12 UTC,-73.960983,40.765547,-73.979177,40.740053,1
# 2011-10-06 12:10:20.0000001,2011-10-06 12:10:20 UTC,-73.949013,40.773204,-73.959622,40.770893,1
# 2011-10-06 12:10:20.0000003,2011-10-06 12:10:20 UTC,-73.777282,40.646636,-73.985083,40.759368,1
# 2011-10-06 12:10:20.0000002,2011-10-06 12:10:20 UTC,-74.014099,40.709638,-73.995106,40.741365,1

# %% [markdown]
# ##Data transformations:
#
# Read input
#
# 1. read training file in chunks, write TFRecords into a separate file for each chunk (roughly 500MB each file)
# 2. ignore number of passengers
# 3. From pickup time, extract features: (1) number of days since 1/1/1990, (2) day of the week, (3) minutes since the start of the day
# 4. Add taxicab distance between pickup and dropoff points

# %%
from dateutil import parser
import datetime
from datetime import date

dt = parser.parse("2016-12-31 19:12:13 UTC")

print dt.year, dt.month, dt.day, dt.hour, dt.minute, dt.timetuple().tm_yday

print dt.weekday()

d0 = date(2008, 8, 18)
d1 = date(2008, 9, 26)
delta = d1 - d0
print delta.days
# Out:
# 2016 12 31 19 12 366
# 5
# 39

# %% [markdown]
# ## Writing into TFRecord file

# %%
import tensorflow as tf
import pandas as pd
from dateutil import parser
import datetime
from datetime import date
import math

def get_features(row):
  complete = True
  fare_amount = row['fare_amount']
  pickup_datetime = row['pickup_datetime']
  pickup_longitude = row['pickup_longitude']
  pickup_latitude = row['pickup_latitude']
  dropoff_longitude = row['dropoff_longitude']
  dropoff_latitude = row['dropoff_latitude']
  if math.isnan(dropoff_longitude) or math.isnan(dropoff_latitude) or math.isnan(pickup_longitude) or math.isnan(pickup_latitude) or pickup_datetime==False or math.isnan(fare_amount) or pickup_longitude==0:
    complete = False
  dt = parser.parse(pickup_datetime)
  year = dt.year
  day_of_year = dt.timetuple().tm_yday
  day_of_week = dt.weekday()
  minutes_since_midnight = (dt.hour * 60) + dt.minute
  distance= 1000*((pickup_latitude-dropoff_latitude)**2 + (pickup_longitude-dropoff_longitude)**2)**.5
  features = {
      "pickup_longitude": tf.train.Feature(float_list = tf.train.FloatList(value=[pickup_longitude])),
      "pickup_latitude": tf.train.Feature(float_list = tf.train.FloatList(value=[pickup_latitude])),
      "fare": tf.train.Feature(float_list = tf.train.FloatList(value=[fare_amount])),
      "distance": tf.train.Feature(float_list = tf.train.FloatList(value=[distance])),
      "year": tf.train.Feature(float_list = tf.train.FloatList(value=[year])),
      "day_of_year": tf.train.Feature(float_list = tf.train.FloatList(value=[day_of_year])),
      "day_of_week": tf.train.Feature(float_list = tf.train.FloatList(value=[day_of_week])),
      "minutes_since_midnight": tf.train.Feature(float_list = tf.train.FloatList(value=[minutes_since_midnight])),
      "dropoff_longitude": tf.train.Feature(float_list = tf.train.FloatList(value=[dropoff_longitude])),
      "dropoff_latitude": tf.train.Feature(float_list = tf.train.FloatList(value=[dropoff_latitude])),
  }
  return (features, complete)

chunk_id = 0

for df in pd.read_csv('train.csv', chunksize=100000):
  chunk_id += 1
  tfr_file = ("training_examples_{id}.tfr".format(id=chunk_id))
  print "generating TFRecord file " + tfr_file
  writer = tf.python_io.TFRecordWriter(tfr_file)

  # For int features:
  # 'name': tf.train.Feature(int64_list = tf.train.Int64List(value = ...))
  # For float features:
  # 'name': tf.train.Feature(float_list = tf.train.FloatList(value = ...))

  for index, row in df.iterrows():
    features_map, is_complete = get_features(row)
    if is_complete:
      example = tf.train.Example(features=tf.train.Features(feature=features_map))
      writer.write(example.SerializeToString())

  writer.close()
# Out:
# generating TFRecord file training_examples_1.tfr
# generating TFRecord file training_examples_2.tfr
# generating TFRecord file training_examples_3.tfr
# generating TFRecord file training_examples_4.tfr
# generating TFRecord file training_examples_5.tfr
# generating TFRecord file training_examples_6.tfr
# generating TFRecord file training_examples_7.tfr
# generating TFRecord file training_examples_8.tfr
# generating TFRecord file training_examples_9.tfr
# generating TFRecord file training_examples_10.tfr
# generating TFRecord file training_examples_11.tfr
# generating TFRecord file training_examples_12.tfr
# generating TFRecord file training_examples_13.tfr
# generating TFRecord file training_examples_14.tfr
# generating TFRecord file training_examples_15.tfr
# generating TFRecord file training_examples_16.tfr
# generating TFRecord file training_examples_17.tfr
# generating TFRecord file training_examples_18.tfr
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-5-c0ff917e01b8> in <module>()
#      50
#      51   for index, row in df.iterrows():
# ---> 52     features_map, is_complete = get_features(row)
#      53     if is_complete:
#      54       example = tf.train.Example(features=tf.train.Features(feature=features_map))
#
# <ipython-input-5-c0ff917e01b8> in get_features(row)
#      16   if math.isnan(dropoff_longitude) or math.isnan(dropoff_latitude) or math.isnan(pickup_longitude) or math.isnan(pickup_latitude) or pickup_datetime==False or math.isnan(fare_amount) or pickup_longitude==0:
#      17     complete = False
# ---> 18   dt = parser.parse(pickup_datetime)
#      19   year = dt.year
#      20   day_of_year = dt.timetuple().tm_yday
#
# /usr/local/lib/python2.7/dist-packages/dateutil/parser.pyc in parse(timestr, parserinfo, **kwargs)
#    1162         return parser(parserinfo).parse(timestr, **kwargs)
#    1163     else:
# -> 1164         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1165
#    1166
#
# /usr/local/lib/python2.7/dist-packages/dateutil/parser.pyc in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     545         if default is None:
#     546             effective_dt = datetime.datetime.now()
# --> 547             default = datetime.datetime.now().replace(hour=0, minute=0,
#     548                                                       second=0, microsecond=0)
#     549         else:
#
# KeyboardInterrupt:

# %%
# !ls -l
# Out:
# total 6045216
# -rw-r--r-- 1 root root       2719 Feb 12 20:47 adc.json
# drwxr-xr-x 1 root root       4096 Feb 11 17:40 sample_data
# -rw-r--r-- 1 root root     983020 Feb 12 20:49 test.csv
# -rw-r--r-- 1 root root 5697178298 Feb 12 20:49 train.csv
# -rw-r--r-- 1 root root   27760602 Feb 12 21:00 training_examples_10.tfr
# -rw-r--r-- 1 root root   27778997 Feb 12 21:00 training_examples_11.tfr
# -rw-r--r-- 1 root root   27774186 Feb 12 21:01 training_examples_12.tfr
# -rw-r--r-- 1 root root   27765413 Feb 12 21:02 training_examples_13.tfr
# -rw-r--r-- 1 root root   27761734 Feb 12 21:03 training_examples_14.tfr
# -rw-r--r-- 1 root root   27771356 Feb 12 21:04 training_examples_15.tfr
# -rw-r--r-- 1 root root   27760885 Feb 12 21:05 training_examples_16.tfr
# -rw-r--r-- 1 root root   27759470 Feb 12 21:06 training_examples_17.tfr
# -rw-r--r-- 1 root root   20033536 Feb 12 21:07 training_examples_18.tfr
# -rw-r--r-- 1 root root   27756074 Feb 12 20:51 training_examples_1.tfr
# -rw-r--r-- 1 root root   27775318 Feb 12 20:52 training_examples_2.tfr
# -rw-r--r-- 1 root root   27781261 Feb 12 20:53 training_examples_3.tfr
# -rw-r--r-- 1 root root   27751829 Feb 12 20:54 training_examples_4.tfr
# -rw-r--r-- 1 root root   27765130 Feb 12 20:55 training_examples_5.tfr
# -rw-r--r-- 1 root root   27773054 Feb 12 20:56 training_examples_6.tfr
# -rw-r--r-- 1 root root   27787487 Feb 12 20:57 training_examples_7.tfr
# -rw-r--r-- 1 root root   27780129 Feb 12 20:58 training_examples_8.tfr
# -rw-r--r-- 1 root root   27751263 Feb 12 20:59 training_examples_9.tfr

# %% [markdown]
# ##Input function for feeding training examples into the model

# %%
import tensorflow as tf

feature_columns = [
    tf.feature_column.numeric_column('pickup_longitude', shape=(1,), dtype=tf.float32),
    tf.feature_column.numeric_column('pickup_latitude', shape=(1,), dtype=tf.float32),
    tf.feature_column.numeric_column('dropoff_longitude', shape=(1,), dtype=tf.float32),
    tf.feature_column.numeric_column('dropoff_latitude', shape=(1,), dtype=tf.float32),
    tf.feature_column.numeric_column('distance', shape=(1,), dtype=tf.float32),
    tf.feature_column.numeric_column('year', shape=(1,), dtype=tf.float32),
    tf.feature_column.numeric_column('day_of_year', shape=(1,), dtype=tf.float32),
    tf.feature_column.numeric_column('day_of_week', shape=(1,), dtype=tf.float32),
    tf.feature_column.numeric_column('minutes_since_midnight', shape=(1,), dtype=tf.float32),
]

label_column = tf.feature_column.numeric_column('fare', shape=(1,), dtype=tf.float32)

features_spec = tf.feature_column.make_parse_example_spec(
    feature_columns + [label_column]
)

def input_fn(file_list, num_epochs):
  dataset = tf.contrib.data.make_batched_features_dataset(
      file_pattern=file_list,
      batch_size=128,
      features=features_spec,
      num_epochs=num_epochs,
      shuffle=True,
      shuffle_buffer_size=10000
  )
  it = dataset.make_one_shot_iterator()
  features = it.get_next()
  print features
  labels = features.pop('fare')
  return features, labels
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/feature_column/feature_column.py:800: _parse_example_spec (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.

# %% [markdown]
# ##Training the model

# %%
#Run once only
# !rm -r model_dir
# !mkdir model_dir
# Out:
# rm: cannot remove 'model_dir': No such file or directory

# %%
model_dir="model_dir"

regressor = tf.estimator.DNNRegressor(
    hidden_units=[32,16,8],
    feature_columns=feature_columns,
    model_dir=model_dir
)

def get_eval_metrics(labels, predictions):
  return {
      'rmse': tf.metrics.root_mean_squared_error(
          labels=labels,
          predictions=predictions['predictions']
      )
  }

regressor = tf.contrib.estimator.add_metrics(regressor, get_eval_metrics)

training_files = [ "training_examples_%d.tfr" % id for id in range(10) ]
testing_files = [ "training_examples_%d.tfr" % id for id in range(10,15) ]

train_spec = tf.estimator.TrainSpec(
    input_fn=lambda: input_fn(training_files, 1),
    max_steps=10000000
)

eval_spec = tf.estimator.EvalSpec(
    input_fn=lambda: input_fn(testing_files, 1),
    steps=None,
    start_delay_secs=10,
    throttle_secs=0
)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe323534250>, '_model_dir': 'model_dir', '_protocol': None, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_device_fn': None, '_experimental_distribute': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_evaluation_master': '', '_eval_distribute': None, '_train_distribute': None, '_master': ''}
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe31c8fbb50>, '_model_dir': 'model_dir', '_protocol': None, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_device_fn': None, '_experimental_distribute': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_evaluation_master': '', '_eval_distribute': None, '_train_distribute': None, '_master': ''}

# %%
while True:
  tf.estimator.train_and_evaluate(regressor, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-7-4148bad44a52>:28: make_batched_features_dataset (from tensorflow.contrib.data.python.ops.readers) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.make_batched_features_dataset(...)`.
# WARNING:tensorflow:From <ipython-input-7-4148bad44a52>:30: make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into model_dir/model.ckpt.
# INFO:tensorflow:loss = 107429.56, step = 0
# INFO:tensorflow:global_step/sec: 194.123
# INFO:tensorflow:loss = 15273.576, step = 100 (0.517 sec)
# INFO:tensorflow:global_step/sec: 262.435
# INFO:tensorflow:loss = 6347.358, step = 200 (0.384 sec)
# INFO:tensorflow:global_step/sec: 263.691
# INFO:tensorflow:loss = 5025.3555, step = 300 (0.377 sec)
# INFO:tensorflow:global_step/sec: 226.934
# INFO:tensorflow:loss = 8045.592, step = 400 (0.442 sec)
# INFO:tensorflow:global_step/sec: 203.584
# INFO:tensorflow:loss = 9087.248, step = 500 (0.493 sec)
# INFO:tensorflow:global_step/sec: 224.104
# INFO:tensorflow:loss = 19463.518, step = 600 (0.445 sec)
# INFO:tensorflow:global_step/sec: 231.357
# INFO:tensorflow:loss = 4099.0776, step = 700 (0.433 sec)
# INFO:tensorflow:global_step/sec: 230.093
# INFO:tensorflow:loss = 8895.862, step = 800 (0.434 sec)
# INFO:tensorflow:global_step/sec: 229.854
# INFO:tensorflow:loss = 9861.579, step = 900 (0.433 sec)
# INFO:tensorflow:global_step/sec: 226.364
# INFO:tensorflow:loss = 3324.9631, step = 1000 (0.441 sec)
# INFO:tensorflow:global_step/sec: 234.346
# INFO:tensorflow:loss = 2734.1462, step = 1100 (0.431 sec)
# INFO:tensorflow:global_step/sec: 232.85
# INFO:tensorflow:loss = 5056.0776, step = 1200 (0.425 sec)
# INFO:tensorflow:global_step/sec: 226.424
# INFO:tensorflow:loss = 1415.6703, step = 1300 (0.442 sec)
# INFO:tensorflow:global_step/sec: 234.621
# INFO:tensorflow:loss = 3416.5579, step = 1400 (0.429 sec)
# INFO:tensorflow:global_step/sec: 225.799
# INFO:tensorflow:loss = 2881.4604, step = 1500 (0.444 sec)
# INFO:tensorflow:global_step/sec: 233.837
# INFO:tensorflow:loss = 1044.1714, step = 1600 (0.426 sec)
# INFO:tensorflow:global_step/sec: 223.84
# INFO:tensorflow:loss = 1069.2655, step = 1700 (0.449 sec)
# INFO:tensorflow:global_step/sec: 232.197
# INFO:tensorflow:loss = 1446.1755, step = 1800 (0.426 sec)
# INFO:tensorflow:global_step/sec: 229.828
# INFO:tensorflow:loss = 3635.837, step = 1900 (0.440 sec)
# INFO:tensorflow:global_step/sec: 226.112
# INFO:tensorflow:loss = 911.5805, step = 2000 (0.441 sec)
# INFO:tensorflow:global_step/sec: 233.244
# INFO:tensorflow:loss = 2221.6152, step = 2100 (0.425 sec)
# INFO:tensorflow:global_step/sec: 228.977
# INFO:tensorflow:loss = 6091.8613, step = 2200 (0.440 sec)
# INFO:tensorflow:global_step/sec: 231.248
# INFO:tensorflow:loss = 941.97144, step = 2300 (0.432 sec)
# INFO:tensorflow:global_step/sec: 228.108
# INFO:tensorflow:loss = 6545.358, step = 2400 (0.437 sec)
# INFO:tensorflow:global_step/sec: 235.886
# INFO:tensorflow:loss = 4270.037, step = 2500 (0.422 sec)
# INFO:tensorflow:global_step/sec: 236.101
# INFO:tensorflow:loss = 7335.275, step = 2600 (0.427 sec)
# INFO:tensorflow:global_step/sec: 228.898
# INFO:tensorflow:loss = 1510.6277, step = 2700 (0.437 sec)
# INFO:tensorflow:global_step/sec: 232.62
# INFO:tensorflow:loss = 3591.2847, step = 2800 (0.428 sec)
# INFO:tensorflow:global_step/sec: 228.749
# INFO:tensorflow:loss = 3821.8132, step = 2900 (0.438 sec)
# INFO:tensorflow:global_step/sec: 230.296
# INFO:tensorflow:loss = 824.8724, step = 3000 (0.434 sec)
# INFO:tensorflow:global_step/sec: 225.796
# INFO:tensorflow:loss = 1696.637, step = 3100 (0.442 sec)
# INFO:tensorflow:global_step/sec: 234.7
# INFO:tensorflow:loss = 1309.3488, step = 3200 (0.427 sec)
# INFO:tensorflow:global_step/sec: 229.97
# INFO:tensorflow:loss = 30072.57, step = 3300 (0.431 sec)
# INFO:tensorflow:global_step/sec: 229.233
# INFO:tensorflow:loss = 2601.024, step = 3400 (0.440 sec)
# INFO:tensorflow:global_step/sec: 234.354
# INFO:tensorflow:loss = 1746.7822, step = 3500 (0.426 sec)
# INFO:tensorflow:global_step/sec: 226.988
# INFO:tensorflow:loss = 3313.3276, step = 3600 (0.439 sec)
# INFO:tensorflow:global_step/sec: 234.455
# INFO:tensorflow:loss = 2330.1448, step = 3700 (0.429 sec)
# INFO:tensorflow:global_step/sec: 240.292
# INFO:tensorflow:loss = 3457.1023, step = 3800 (0.415 sec)
# INFO:tensorflow:global_step/sec: 227.325
# INFO:tensorflow:loss = 1156.4619, step = 3900 (0.444 sec)
# INFO:tensorflow:global_step/sec: 234.895
# INFO:tensorflow:loss = 3837.4858, step = 4000 (0.422 sec)
# INFO:tensorflow:global_step/sec: 229.47
# INFO:tensorflow:loss = 4866.896, step = 4100 (0.437 sec)
# INFO:tensorflow:global_step/sec: 235.078
# INFO:tensorflow:loss = 1289.6631, step = 4200 (0.422 sec)
# INFO:tensorflow:global_step/sec: 230.082
# INFO:tensorflow:loss = 1424.5243, step = 4300 (0.438 sec)
# INFO:tensorflow:global_step/sec: 234.098
# INFO:tensorflow:loss = 1838.6853, step = 4400 (0.425 sec)
# INFO:tensorflow:global_step/sec: 236.438
# INFO:tensorflow:loss = 1858.1542, step = 4500 (0.422 sec)
# INFO:tensorflow:global_step/sec: 228.975
# INFO:tensorflow:loss = 1593.513, step = 4600 (0.437 sec)
# INFO:tensorflow:global_step/sec: 238.538
# INFO:tensorflow:loss = 11827.273, step = 4700 (0.418 sec)
# INFO:tensorflow:global_step/sec: 238.125
# INFO:tensorflow:loss = 1222.4757, step = 4800 (0.423 sec)
# INFO:tensorflow:global_step/sec: 239.026
# INFO:tensorflow:loss = 7918.791, step = 4900 (0.419 sec)
# INFO:tensorflow:global_step/sec: 236.276
# INFO:tensorflow:loss = 1259.209, step = 5000 (0.424 sec)
# INFO:tensorflow:global_step/sec: 228.852
# INFO:tensorflow:loss = 841.4469, step = 5100 (0.434 sec)
# INFO:tensorflow:global_step/sec: 235.905
# INFO:tensorflow:loss = 3810.6519, step = 5200 (0.427 sec)
# INFO:tensorflow:global_step/sec: 233.064
# INFO:tensorflow:loss = 3210.0332, step = 5300 (0.428 sec)
# INFO:tensorflow:global_step/sec: 238.749
# INFO:tensorflow:loss = 3288.3977, step = 5400 (0.418 sec)
# INFO:tensorflow:global_step/sec: 233.84
# INFO:tensorflow:loss = 3671.301, step = 5500 (0.426 sec)
# INFO:tensorflow:global_step/sec: 240.614
# INFO:tensorflow:loss = 1610.1736, step = 5600 (0.419 sec)
# INFO:tensorflow:global_step/sec: 231.854
# INFO:tensorflow:loss = 7432.338, step = 5700 (0.429 sec)
# INFO:tensorflow:global_step/sec: 230.475
# INFO:tensorflow:loss = 2601.3176, step = 5800 (0.436 sec)
# INFO:tensorflow:global_step/sec: 233.657
# INFO:tensorflow:loss = 2369.386, step = 5900 (0.425 sec)
# INFO:tensorflow:global_step/sec: 226.817
# INFO:tensorflow:loss = 5346.0366, step = 6000 (0.439 sec)
# INFO:tensorflow:global_step/sec: 233.631
# INFO:tensorflow:loss = 1154.86, step = 6100 (0.428 sec)
# INFO:tensorflow:global_step/sec: 237.631
# INFO:tensorflow:loss = 1225.8798, step = 6200 (0.424 sec)
# INFO:tensorflow:global_step/sec: 234.642
# INFO:tensorflow:loss = 7404.275, step = 6300 (0.426 sec)
# INFO:tensorflow:global_step/sec: 230.979
# INFO:tensorflow:loss = 3753.826, step = 6400 (0.433 sec)
# INFO:tensorflow:global_step/sec: 233.803
# INFO:tensorflow:loss = 1521.5884, step = 6500 (0.429 sec)
# INFO:tensorflow:global_step/sec: 241.187
# INFO:tensorflow:loss = 4156.8926, step = 6600 (0.416 sec)
# INFO:tensorflow:global_step/sec: 234.071
# INFO:tensorflow:loss = 1043.1997, step = 6700 (0.425 sec)
# INFO:tensorflow:global_step/sec: 236.145
# INFO:tensorflow:loss = 2341.2844, step = 6800 (0.426 sec)
# INFO:tensorflow:Saving checkpoints for 6900 into model_dir/model.ckpt.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-12T21:23:56Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-6900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-12-21:24:09
# INFO:tensorflow:Saving dict for global step 6900: average_loss = 26.126987, global_step = 6900, label/mean = 11.332457, loss = 3344.1182, prediction/mean = 10.643659, rmse = 5.1114564
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6900: model_dir/model.ckpt-6900
# INFO:tensorflow:Loss for final step: 125.65123.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-6900
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/training/saver.py:1070: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6900 into model_dir/model.ckpt.
# INFO:tensorflow:loss = 1196.5365, step = 6900
# INFO:tensorflow:global_step/sec: 205.627
# INFO:tensorflow:loss = 3754.2698, step = 7000 (0.492 sec)
# INFO:tensorflow:global_step/sec: 229.521
# INFO:tensorflow:loss = 3064.0251, step = 7100 (0.435 sec)
# INFO:tensorflow:global_step/sec: 232.632
# INFO:tensorflow:loss = 1237.4192, step = 7200 (0.428 sec)
# INFO:tensorflow:global_step/sec: 231.155
# INFO:tensorflow:loss = 941.0698, step = 7300 (0.432 sec)
# INFO:tensorflow:global_step/sec: 238.145
# INFO:tensorflow:loss = 1660.0332, step = 7400 (0.424 sec)
# INFO:tensorflow:global_step/sec: 235.832
# INFO:tensorflow:loss = 2790.1624, step = 7500 (0.420 sec)
# INFO:tensorflow:global_step/sec: 237.309
# INFO:tensorflow:loss = 1152.749, step = 7600 (0.424 sec)
# INFO:tensorflow:global_step/sec: 236.619
# INFO:tensorflow:loss = 1958.8732, step = 7700 (0.421 sec)
# INFO:tensorflow:global_step/sec: 232.87
# INFO:tensorflow:loss = 1232.0905, step = 7800 (0.431 sec)
# INFO:tensorflow:global_step/sec: 240.218
# INFO:tensorflow:loss = 2971.458, step = 7900 (0.417 sec)
# INFO:tensorflow:global_step/sec: 235.205
# INFO:tensorflow:loss = 924.94165, step = 8000 (0.422 sec)
# INFO:tensorflow:global_step/sec: 237.431
# INFO:tensorflow:loss = 1284.6488, step = 8100 (0.424 sec)
# INFO:tensorflow:global_step/sec: 237.794
# INFO:tensorflow:loss = 3651.0652, step = 8200 (0.419 sec)
# INFO:tensorflow:global_step/sec: 232.046
# INFO:tensorflow:loss = 6349.0728, step = 8300 (0.431 sec)
# INFO:tensorflow:global_step/sec: 238.882
# INFO:tensorflow:loss = 3881.8723, step = 8400 (0.416 sec)
# INFO:tensorflow:global_step/sec: 232.913
# INFO:tensorflow:loss = 1957.7263, step = 8500 (0.432 sec)
# INFO:tensorflow:global_step/sec: 236.529
# INFO:tensorflow:loss = 5576.8687, step = 8600 (0.424 sec)
# INFO:tensorflow:global_step/sec: 237.597
# INFO:tensorflow:loss = 1021.68964, step = 8700 (0.417 sec)
# INFO:tensorflow:global_step/sec: 235.9
# INFO:tensorflow:loss = 2461.1023, step = 8800 (0.427 sec)
# INFO:tensorflow:global_step/sec: 236.964
# INFO:tensorflow:loss = 1163.6348, step = 8900 (0.420 sec)
# INFO:tensorflow:global_step/sec: 228.432
# INFO:tensorflow:loss = 1417.4092, step = 9000 (0.438 sec)
# INFO:tensorflow:global_step/sec: 236.111
# INFO:tensorflow:loss = 2097.7341, step = 9100 (0.423 sec)
# INFO:tensorflow:global_step/sec: 232.515
# INFO:tensorflow:loss = 1290.4865, step = 9200 (0.432 sec)
# INFO:tensorflow:global_step/sec: 232.252
# INFO:tensorflow:loss = 1264.8564, step = 9300 (0.428 sec)
# INFO:tensorflow:global_step/sec: 236.502
# INFO:tensorflow:loss = 16631.715, step = 9400 (0.423 sec)
# INFO:tensorflow:global_step/sec: 232.322
# INFO:tensorflow:loss = 2911.1155, step = 9500 (0.430 sec)
# INFO:tensorflow:global_step/sec: 236.347
# INFO:tensorflow:loss = 964.31415, step = 9600 (0.426 sec)
# INFO:tensorflow:global_step/sec: 231.147
# INFO:tensorflow:loss = 1764.9958, step = 9700 (0.433 sec)
# INFO:tensorflow:global_step/sec: 208.146
# INFO:tensorflow:loss = 2930.5115, step = 9800 (0.478 sec)
# INFO:tensorflow:global_step/sec: 230.486
# INFO:tensorflow:loss = 4135.912, step = 9900 (0.437 sec)
# INFO:tensorflow:global_step/sec: 237.069
# INFO:tensorflow:loss = 1318.0154, step = 10000 (0.417 sec)
# INFO:tensorflow:global_step/sec: 237.878
# INFO:tensorflow:loss = 1244.8616, step = 10100 (0.423 sec)
# INFO:tensorflow:global_step/sec: 232.362
# INFO:tensorflow:loss = 2159.0708, step = 10200 (0.432 sec)
# INFO:tensorflow:global_step/sec: 238.352
# INFO:tensorflow:loss = 3408.8018, step = 10300 (0.416 sec)
# INFO:tensorflow:global_step/sec: 234.271
# INFO:tensorflow:loss = 1683.2238, step = 10400 (0.428 sec)
# INFO:tensorflow:global_step/sec: 237.016
# INFO:tensorflow:loss = 2189.9724, step = 10500 (0.424 sec)
# INFO:tensorflow:global_step/sec: 235.915
# INFO:tensorflow:loss = 3951.1792, step = 10600 (0.424 sec)
# INFO:tensorflow:global_step/sec: 231.671
# INFO:tensorflow:loss = 3586.228, step = 10700 (0.432 sec)
# INFO:tensorflow:global_step/sec: 220.804
# INFO:tensorflow:loss = 1196.3083, step = 10800 (0.450 sec)
# INFO:tensorflow:global_step/sec: 234.075
# INFO:tensorflow:loss = 2150.7998, step = 10900 (0.429 sec)
# INFO:tensorflow:global_step/sec: 236.127
# INFO:tensorflow:loss = 1003.2312, step = 11000 (0.422 sec)
# INFO:tensorflow:global_step/sec: 224.967
# INFO:tensorflow:loss = 20487.676, step = 11100 (0.446 sec)
# INFO:tensorflow:global_step/sec: 239.865
# INFO:tensorflow:loss = 5414.936, step = 11200 (0.414 sec)
# INFO:tensorflow:global_step/sec: 235.814
# INFO:tensorflow:loss = 2076.028, step = 11300 (0.427 sec)
# INFO:tensorflow:global_step/sec: 227.925
# INFO:tensorflow:loss = 1435.6146, step = 11400 (0.440 sec)
# INFO:tensorflow:global_step/sec: 235.151
# INFO:tensorflow:loss = 2453.3127, step = 11500 (0.421 sec)
# INFO:tensorflow:global_step/sec: 229.712
# INFO:tensorflow:loss = 1170.9529, step = 11600 (0.434 sec)
# INFO:tensorflow:global_step/sec: 238.771
# INFO:tensorflow:loss = 951.1587, step = 11700 (0.422 sec)
# INFO:tensorflow:global_step/sec: 241.151
# INFO:tensorflow:loss = 2065.1475, step = 11800 (0.414 sec)
# INFO:tensorflow:global_step/sec: 230.127
# INFO:tensorflow:loss = 4444.1187, step = 11900 (0.436 sec)
# INFO:tensorflow:global_step/sec: 235.134
# INFO:tensorflow:loss = 1022.6283, step = 12000 (0.423 sec)
# INFO:tensorflow:global_step/sec: 230.868
# INFO:tensorflow:loss = 2078.2065, step = 12100 (0.436 sec)
# INFO:tensorflow:global_step/sec: 237.982
# INFO:tensorflow:loss = 1265.1516, step = 12200 (0.421 sec)
# INFO:tensorflow:global_step/sec: 226.468
# INFO:tensorflow:loss = 2963.5198, step = 12300 (0.437 sec)
# INFO:tensorflow:global_step/sec: 236.452
# INFO:tensorflow:loss = 1047.325, step = 12400 (0.423 sec)
# INFO:tensorflow:global_step/sec: 234.211
# INFO:tensorflow:loss = 1129.6296, step = 12500 (0.427 sec)
# INFO:tensorflow:global_step/sec: 232.789
# INFO:tensorflow:loss = 2017.0642, step = 12600 (0.429 sec)
# INFO:tensorflow:global_step/sec: 216.097
# INFO:tensorflow:loss = 858.69696, step = 12700 (0.466 sec)
# INFO:tensorflow:global_step/sec: 229.812
# INFO:tensorflow:loss = 2916.6316, step = 12800 (0.436 sec)
# INFO:tensorflow:global_step/sec: 239.364
# INFO:tensorflow:loss = 1269.2456, step = 12900 (0.417 sec)
# INFO:tensorflow:global_step/sec: 236.722
# INFO:tensorflow:loss = 929.1957, step = 13000 (0.423 sec)
# INFO:tensorflow:global_step/sec: 234.658
# INFO:tensorflow:loss = 4149.7383, step = 13100 (0.426 sec)
# INFO:tensorflow:global_step/sec: 239.359
# INFO:tensorflow:loss = 2390.0037, step = 13200 (0.419 sec)
# INFO:tensorflow:global_step/sec: 234.143
# INFO:tensorflow:loss = 2591.6777, step = 13300 (0.426 sec)
# INFO:tensorflow:global_step/sec: 239.276
# INFO:tensorflow:loss = 3248.4067, step = 13400 (0.424 sec)
# INFO:tensorflow:global_step/sec: 231.515
# INFO:tensorflow:loss = 2050.6821, step = 13500 (0.423 sec)
# INFO:tensorflow:global_step/sec: 238.538
# INFO:tensorflow:loss = 1116.2723, step = 13600 (0.422 sec)
# INFO:tensorflow:global_step/sec: 239.438
# INFO:tensorflow:loss = 7244.193, step = 13700 (0.415 sec)
# INFO:tensorflow:Saving checkpoints for 13800 into model_dir/model.ckpt.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-12T21:24:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-13800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-12-21:24:55
# INFO:tensorflow:Saving dict for global step 13800: average_loss = 25.718132, global_step = 13800, label/mean = 11.332448, loss = 3291.7866, prediction/mean = 11.033814, rmse = 5.071305
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13800: model_dir/model.ckpt-13800
# INFO:tensorflow:Loss for final step: 313.73956.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-13800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13800 into model_dir/model.ckpt.
# INFO:tensorflow:loss = 1543.9277, step = 13800
# INFO:tensorflow:global_step/sec: 196.47
# INFO:tensorflow:loss = 1488.2609, step = 13900 (0.513 sec)
# INFO:tensorflow:global_step/sec: 237.694
# INFO:tensorflow:loss = 11862.387, step = 14000 (0.422 sec)
# INFO:tensorflow:global_step/sec: 230.251
# INFO:tensorflow:loss = 1108.0704, step = 14100 (0.431 sec)
# INFO:tensorflow:global_step/sec: 235.929
# INFO:tensorflow:loss = 1754.6136, step = 14200 (0.425 sec)
# INFO:tensorflow:global_step/sec: 227.037
# INFO:tensorflow:loss = 6418.8716, step = 14300 (0.442 sec)
# INFO:tensorflow:global_step/sec: 234.694
# INFO:tensorflow:loss = 1498.9679, step = 14400 (0.429 sec)
# INFO:tensorflow:global_step/sec: 234.775
# INFO:tensorflow:loss = 1071.3652, step = 14500 (0.425 sec)
# INFO:tensorflow:global_step/sec: 226.794
# INFO:tensorflow:loss = 3118.9067, step = 14600 (0.441 sec)
# INFO:tensorflow:global_step/sec: 233.227
# INFO:tensorflow:loss = 980.92444, step = 14700 (0.429 sec)
# INFO:tensorflow:global_step/sec: 228.01
# INFO:tensorflow:loss = 4254.859, step = 14800 (0.435 sec)
# INFO:tensorflow:global_step/sec: 235.493
# INFO:tensorflow:loss = 1467.3138, step = 14900 (0.425 sec)
# INFO:tensorflow:global_step/sec: 219.94
# INFO:tensorflow:loss = 1291.839, step = 15000 (0.459 sec)
# INFO:tensorflow:global_step/sec: 232.319
# INFO:tensorflow:loss = 1292.7863, step = 15100 (0.428 sec)
# INFO:tensorflow:global_step/sec: 236
# INFO:tensorflow:loss = 7765.385, step = 15200 (0.427 sec)
# INFO:tensorflow:global_step/sec: 230.17
# INFO:tensorflow:loss = 1463.5135, step = 15300 (0.432 sec)
# INFO:tensorflow:global_step/sec: 234.042
# INFO:tensorflow:loss = 1391.9111, step = 15400 (0.429 sec)
# INFO:tensorflow:global_step/sec: 231.389
# INFO:tensorflow:loss = 819.3351, step = 15500 (0.432 sec)
# INFO:tensorflow:global_step/sec: 236.958
# INFO:tensorflow:loss = 1005.9749, step = 15600 (0.419 sec)
# INFO:tensorflow:global_step/sec: 236.355
# INFO:tensorflow:loss = 1597.7828, step = 15700 (0.425 sec)
# INFO:tensorflow:global_step/sec: 231.062
# INFO:tensorflow:loss = 2363.093, step = 15800 (0.434 sec)
# INFO:tensorflow:global_step/sec: 236.955
# INFO:tensorflow:loss = 1065.2285, step = 15900 (0.422 sec)
# INFO:tensorflow:global_step/sec: 228.602
# INFO:tensorflow:loss = 2073.7346, step = 16000 (0.437 sec)
# INFO:tensorflow:global_step/sec: 234.278
# INFO:tensorflow:loss = 1826.0393, step = 16100 (0.424 sec)
# INFO:tensorflow:global_step/sec: 228.473
# INFO:tensorflow:loss = 3175.7974, step = 16200 (0.442 sec)
# INFO:tensorflow:global_step/sec: 232.581
# INFO:tensorflow:loss = 1424.4697, step = 16300 (0.426 sec)
# INFO:tensorflow:global_step/sec: 231.249
# INFO:tensorflow:loss = 860.1017, step = 16400 (0.436 sec)
# INFO:tensorflow:global_step/sec: 230.377
# INFO:tensorflow:loss = 1661.0642, step = 16500 (0.433 sec)
# INFO:tensorflow:global_step/sec: 231.348
# INFO:tensorflow:loss = 867.7397, step = 16600 (0.435 sec)
# INFO:tensorflow:global_step/sec: 234.837
# INFO:tensorflow:loss = 3536.3716, step = 16700 (0.424 sec)
# INFO:tensorflow:global_step/sec: 235.745
# INFO:tensorflow:loss = 4979.5396, step = 16800 (0.423 sec)
# INFO:tensorflow:global_step/sec: 235.877
# INFO:tensorflow:loss = 1607.442, step = 16900 (0.426 sec)
# INFO:tensorflow:global_step/sec: 233.026
# INFO:tensorflow:loss = 4030.9756, step = 17000 (0.428 sec)
# INFO:tensorflow:global_step/sec: 236.473
# INFO:tensorflow:loss = 1264.2307, step = 17100 (0.423 sec)
# INFO:tensorflow:global_step/sec: 214.614
# INFO:tensorflow:loss = 1697.9888, step = 17200 (0.463 sec)
# INFO:tensorflow:global_step/sec: 241.573
# INFO:tensorflow:loss = 19543.598, step = 17300 (0.417 sec)
# INFO:tensorflow:global_step/sec: 232.735
# INFO:tensorflow:loss = 759.97046, step = 17400 (0.430 sec)
# INFO:tensorflow:global_step/sec: 238.203
# INFO:tensorflow:loss = 1980.4646, step = 17500 (0.415 sec)
# INFO:tensorflow:global_step/sec: 239.558
# INFO:tensorflow:loss = 2075.1206, step = 17600 (0.421 sec)
# INFO:tensorflow:global_step/sec: 232.635
# INFO:tensorflow:loss = 1647.4375, step = 17700 (0.430 sec)
# INFO:tensorflow:global_step/sec: 237.542
# INFO:tensorflow:loss = 1515.2153, step = 17800 (0.421 sec)
# INFO:tensorflow:global_step/sec: 230.536
# INFO:tensorflow:loss = 2155.4478, step = 17900 (0.430 sec)
# INFO:tensorflow:global_step/sec: 236.057
# INFO:tensorflow:loss = 2469.9702, step = 18000 (0.424 sec)
# INFO:tensorflow:global_step/sec: 234.622
# INFO:tensorflow:loss = 1689.0588, step = 18100 (0.429 sec)
# INFO:tensorflow:global_step/sec: 233.432
# INFO:tensorflow:loss = 1457.5012, step = 18200 (0.426 sec)
# INFO:tensorflow:global_step/sec: 234.87
# INFO:tensorflow:loss = 11845.749, step = 18300 (0.428 sec)
# INFO:tensorflow:global_step/sec: 226.744
# INFO:tensorflow:loss = 2093.8875, step = 18400 (0.439 sec)
# INFO:tensorflow:global_step/sec: 237.482
# INFO:tensorflow:loss = 1760.4794, step = 18500 (0.423 sec)
# INFO:tensorflow:global_step/sec: 236.273
# INFO:tensorflow:loss = 3542.5583, step = 18600 (0.422 sec)
# INFO:tensorflow:global_step/sec: 235.629
# INFO:tensorflow:loss = 1196.7134, step = 18700 (0.425 sec)
# INFO:tensorflow:global_step/sec: 241.509
# INFO:tensorflow:loss = 1510.828, step = 18800 (0.414 sec)
# INFO:tensorflow:global_step/sec: 231.609
# INFO:tensorflow:loss = 1109.1718, step = 18900 (0.432 sec)
# INFO:tensorflow:global_step/sec: 224.045
# INFO:tensorflow:loss = 2895.335, step = 19000 (0.447 sec)
# INFO:tensorflow:global_step/sec: 231.468
# INFO:tensorflow:loss = 4092.7354, step = 19100 (0.428 sec)
# INFO:tensorflow:global_step/sec: 231.522
# INFO:tensorflow:loss = 6436.0664, step = 19200 (0.432 sec)
# INFO:tensorflow:global_step/sec: 225.57
# INFO:tensorflow:loss = 4538.5415, step = 19300 (0.449 sec)
# INFO:tensorflow:global_step/sec: 226.424
# INFO:tensorflow:loss = 2484.866, step = 19400 (0.436 sec)
# INFO:tensorflow:global_step/sec: 230.897
# INFO:tensorflow:loss = 896.1603, step = 19500 (0.436 sec)
# INFO:tensorflow:global_step/sec: 223.567
# INFO:tensorflow:loss = 1196.0618, step = 19600 (0.447 sec)
# INFO:tensorflow:global_step/sec: 231.481
# INFO:tensorflow:loss = 1432.553, step = 19700 (0.433 sec)
# INFO:tensorflow:global_step/sec: 224.076
# INFO:tensorflow:loss = 5607.277, step = 19800 (0.446 sec)
# INFO:tensorflow:global_step/sec: 223.134
# INFO:tensorflow:loss = 3100.6648, step = 19900 (0.448 sec)
# INFO:tensorflow:global_step/sec: 221.667
# INFO:tensorflow:loss = 1200.7393, step = 20000 (0.452 sec)
# INFO:tensorflow:global_step/sec: 219.259
# INFO:tensorflow:loss = 2143.58, step = 20100 (0.456 sec)
# INFO:tensorflow:global_step/sec: 219.813
# INFO:tensorflow:loss = 1017.683, step = 20200 (0.454 sec)
# INFO:tensorflow:global_step/sec: 226.222
# INFO:tensorflow:loss = 1455.6506, step = 20300 (0.443 sec)
# INFO:tensorflow:global_step/sec: 225.763
# INFO:tensorflow:loss = 1265.5154, step = 20400 (0.439 sec)
# INFO:tensorflow:global_step/sec: 228.065
# INFO:tensorflow:loss = 2745.469, step = 20500 (0.439 sec)
# INFO:tensorflow:global_step/sec: 228.57
# INFO:tensorflow:loss = 1516.8098, step = 20600 (0.438 sec)
# INFO:tensorflow:Saving checkpoints for 20700 into model_dir/model.ckpt.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-12T21:25:27Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-20700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-12-21:25:41
# INFO:tensorflow:Saving dict for global step 20700: average_loss = 25.646248, global_step = 20700, label/mean = 11.332452, loss = 3282.586, prediction/mean = 11.442896, rmse = 5.0642123
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20700: model_dir/model.ckpt-20700
# INFO:tensorflow:Loss for final step: 710.4114.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-20700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 20700 into model_dir/model.ckpt.
# INFO:tensorflow:loss = 1100.9393, step = 20700
# INFO:tensorflow:global_step/sec: 203.282
# INFO:tensorflow:loss = 3957.1284, step = 20800 (0.498 sec)
# INFO:tensorflow:global_step/sec: 230.525
# INFO:tensorflow:loss = 2839.477, step = 20900 (0.433 sec)
# INFO:tensorflow:global_step/sec: 237.361
# INFO:tensorflow:loss = 3169.8567, step = 21000 (0.422 sec)
# INFO:tensorflow:global_step/sec: 233.973
# INFO:tensorflow:loss = 4846.892, step = 21100 (0.424 sec)
# INFO:tensorflow:global_step/sec: 238.026
# INFO:tensorflow:loss = 1758.9246, step = 21200 (0.425 sec)
# INFO:tensorflow:global_step/sec: 227.359
# INFO:tensorflow:loss = 4882.2446, step = 21300 (0.436 sec)
# INFO:tensorflow:global_step/sec: 239.777
# INFO:tensorflow:loss = 17212.922, step = 21400 (0.422 sec)
# INFO:tensorflow:global_step/sec: 233.811
# INFO:tensorflow:loss = 820.65765, step = 21500 (0.426 sec)
# INFO:tensorflow:global_step/sec: 232.585
# INFO:tensorflow:loss = 1613.7981, step = 21600 (0.427 sec)
# INFO:tensorflow:global_step/sec: 237.77
# INFO:tensorflow:loss = 2847.539, step = 21700 (0.422 sec)
# INFO:tensorflow:global_step/sec: 230.922
# INFO:tensorflow:loss = 2387.0894, step = 21800 (0.435 sec)
# INFO:tensorflow:global_step/sec: 236.624
# INFO:tensorflow:loss = 1582.1653, step = 21900 (0.422 sec)
# INFO:tensorflow:global_step/sec: 231.753
# INFO:tensorflow:loss = 1278.9816, step = 22000 (0.428 sec)
# INFO:tensorflow:global_step/sec: 230.406
# INFO:tensorflow:loss = 1815.9882, step = 22100 (0.437 sec)
# INFO:tensorflow:global_step/sec: 234.252
# INFO:tensorflow:loss = 2995.8145, step = 22200 (0.425 sec)
# INFO:tensorflow:global_step/sec: 231.874
# INFO:tensorflow:loss = 3922.258, step = 22300 (0.433 sec)
# INFO:tensorflow:global_step/sec: 234.025
# INFO:tensorflow:loss = 2714.6704, step = 22400 (0.427 sec)
# INFO:tensorflow:global_step/sec: 231.386
# INFO:tensorflow:loss = 1446.023, step = 22500 (0.432 sec)
# INFO:tensorflow:global_step/sec: 242.477
# INFO:tensorflow:loss = 3844.4927, step = 22600 (0.414 sec)
# INFO:tensorflow:global_step/sec: 233.906
# INFO:tensorflow:loss = 3512.945, step = 22700 (0.424 sec)
# INFO:tensorflow:global_step/sec: 236.901
# INFO:tensorflow:loss = 5391.472, step = 22800 (0.425 sec)
# INFO:tensorflow:global_step/sec: 239.287
# INFO:tensorflow:loss = 2781.515, step = 22900 (0.416 sec)
# INFO:tensorflow:global_step/sec: 234.084
# INFO:tensorflow:loss = 3330.2434, step = 23000 (0.429 sec)
# INFO:tensorflow:global_step/sec: 242.881
# INFO:tensorflow:loss = 3084.0457, step = 23100 (0.411 sec)
# INFO:tensorflow:global_step/sec: 239.234
# INFO:tensorflow:loss = 2427.8706, step = 23200 (0.420 sec)
# INFO:tensorflow:global_step/sec: 234.465
# INFO:tensorflow:loss = 5235.074, step = 23300 (0.422 sec)
# INFO:tensorflow:global_step/sec: 236.745
# INFO:tensorflow:loss = 1110.4188, step = 23400 (0.423 sec)
# INFO:tensorflow:global_step/sec: 231.762
# INFO:tensorflow:loss = 1160.4885, step = 23500 (0.431 sec)
# INFO:tensorflow:global_step/sec: 242.13
# INFO:tensorflow:loss = 2665.7622, step = 23600 (0.417 sec)
# INFO:tensorflow:global_step/sec: 231.73
# INFO:tensorflow:loss = 1016.36975, step = 23700 (0.433 sec)
# INFO:tensorflow:global_step/sec: 238.922
# INFO:tensorflow:loss = 1152.7675, step = 23800 (0.414 sec)
# INFO:tensorflow:global_step/sec: 239.387
# INFO:tensorflow:loss = 1380.5935, step = 23900 (0.417 sec)
# INFO:tensorflow:global_step/sec: 228.909
# INFO:tensorflow:loss = 972.81995, step = 24000 (0.437 sec)
# INFO:tensorflow:global_step/sec: 236.573
# INFO:tensorflow:loss = 1453.0664, step = 24100 (0.423 sec)
# INFO:tensorflow:global_step/sec: 233.387
# INFO:tensorflow:loss = 5092.0396, step = 24200 (0.432 sec)
# INFO:tensorflow:global_step/sec: 233.686
# INFO:tensorflow:loss = 3455.4773, step = 24300 (0.427 sec)
# INFO:tensorflow:global_step/sec: 240.664
# INFO:tensorflow:loss = 2418.5457, step = 24400 (0.412 sec)
# INFO:tensorflow:global_step/sec: 231.149
# INFO:tensorflow:loss = 1357.9442, step = 24500 (0.432 sec)
# INFO:tensorflow:global_step/sec: 240.868
# INFO:tensorflow:loss = 1173.8672, step = 24600 (0.417 sec)
# INFO:tensorflow:global_step/sec: 228.273
# INFO:tensorflow:loss = 2464.9915, step = 24700 (0.438 sec)
# INFO:tensorflow:global_step/sec: 233.293
# INFO:tensorflow:loss = 7088.8374, step = 24800 (0.426 sec)
# INFO:tensorflow:global_step/sec: 238.139
# INFO:tensorflow:loss = 1327.1665, step = 24900 (0.420 sec)
# INFO:tensorflow:global_step/sec: 229.928
# INFO:tensorflow:loss = 2137.4443, step = 25000 (0.439 sec)
# INFO:tensorflow:global_step/sec: 236.332
# INFO:tensorflow:loss = 2485.123, step = 25100 (0.421 sec)
# INFO:tensorflow:global_step/sec: 227.737
# INFO:tensorflow:loss = 1357.7285, step = 25200 (0.443 sec)
# INFO:tensorflow:global_step/sec: 235.573
# INFO:tensorflow:loss = 3281.5984, step = 25300 (0.422 sec)
# INFO:tensorflow:global_step/sec: 226.232
# INFO:tensorflow:loss = 2746.2634, step = 25400 (0.441 sec)
# INFO:tensorflow:global_step/sec: 238.623
# INFO:tensorflow:loss = 877.9691, step = 25500 (0.417 sec)
# INFO:tensorflow:global_step/sec: 239.446
# INFO:tensorflow:loss = 8501.899, step = 25600 (0.417 sec)
# INFO:tensorflow:global_step/sec: 236.42
# INFO:tensorflow:loss = 1404.4061, step = 25700 (0.426 sec)
# INFO:tensorflow:global_step/sec: 234.407
# INFO:tensorflow:loss = 609.22766, step = 25800 (0.424 sec)
# INFO:tensorflow:global_step/sec: 226.213
# INFO:tensorflow:loss = 3069.3066, step = 25900 (0.445 sec)
# INFO:tensorflow:global_step/sec: 239.045
# INFO:tensorflow:loss = 3520.728, step = 26000 (0.419 sec)
# INFO:tensorflow:global_step/sec: 232.009
# INFO:tensorflow:loss = 3398.517, step = 26100 (0.432 sec)
# INFO:tensorflow:global_step/sec: 233.196
# INFO:tensorflow:loss = 4084.2236, step = 26200 (0.426 sec)
# INFO:tensorflow:global_step/sec: 241.732
# INFO:tensorflow:loss = 3572.7764, step = 26300 (0.415 sec)
# INFO:tensorflow:global_step/sec: 228.92
# INFO:tensorflow:loss = 1354.8074, step = 26400 (0.434 sec)
# INFO:tensorflow:global_step/sec: 233.53
# INFO:tensorflow:loss = 5986.4507, step = 26500 (0.428 sec)
# INFO:tensorflow:global_step/sec: 230.108
# INFO:tensorflow:loss = 4759.0713, step = 26600 (0.438 sec)
# INFO:tensorflow:global_step/sec: 236.646
# INFO:tensorflow:loss = 7283.0215, step = 26700 (0.422 sec)
# INFO:tensorflow:global_step/sec: 236.198
# INFO:tensorflow:loss = 3644.4736, step = 26800 (0.426 sec)
# INFO:tensorflow:global_step/sec: 223.713
# INFO:tensorflow:loss = 751.1614, step = 26900 (0.444 sec)
# INFO:tensorflow:global_step/sec: 234.634
# INFO:tensorflow:loss = 1186.1108, step = 27000 (0.428 sec)
# INFO:tensorflow:global_step/sec: 224.602
# INFO:tensorflow:loss = 1874.3531, step = 27100 (0.445 sec)
# INFO:tensorflow:global_step/sec: 235.561
# INFO:tensorflow:loss = 12987.676, step = 27200 (0.421 sec)
# INFO:tensorflow:global_step/sec: 228.974
# INFO:tensorflow:loss = 1502.5645, step = 27300 (0.440 sec)
# INFO:tensorflow:global_step/sec: 233.821
# INFO:tensorflow:loss = 953.10913, step = 27400 (0.426 sec)
# INFO:tensorflow:global_step/sec: 235.704
# INFO:tensorflow:loss = 3931.8193, step = 27500 (0.423 sec)
# INFO:tensorflow:Saving checkpoints for 27600 into model_dir/model.ckpt.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-12T21:26:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-27600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-12-21:26:26
# INFO:tensorflow:Saving dict for global step 27600: average_loss = 25.694902, global_step = 27600, label/mean = 11.332448, loss = 3288.8135, prediction/mean = 11.0584755, rmse = 5.069014
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 27600: model_dir/model.ckpt-27600
# INFO:tensorflow:Loss for final step: 433.57208.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-27600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 27600 into model_dir/model.ckpt.
# INFO:tensorflow:loss = 21594.652, step = 27600
# INFO:tensorflow:global_step/sec: 194.733
# INFO:tensorflow:loss = 1547.1445, step = 27700 (0.518 sec)
# INFO:tensorflow:global_step/sec: 235.224
# INFO:tensorflow:loss = 3806.8318, step = 27800 (0.423 sec)
# INFO:tensorflow:global_step/sec: 225.451
# INFO:tensorflow:loss = 3169.5662, step = 27900 (0.444 sec)
# INFO:tensorflow:global_step/sec: 231.643
# INFO:tensorflow:loss = 1853.05, step = 28000 (0.433 sec)
# INFO:tensorflow:global_step/sec: 231.13
# INFO:tensorflow:loss = 3337.4177, step = 28100 (0.434 sec)
# INFO:tensorflow:global_step/sec: 232.455
# INFO:tensorflow:loss = 1292.3522, step = 28200 (0.426 sec)
# INFO:tensorflow:global_step/sec: 236.04
# INFO:tensorflow:loss = 1222.8285, step = 28300 (0.425 sec)
# INFO:tensorflow:global_step/sec: 228.288
# INFO:tensorflow:loss = 1078.0662, step = 28400 (0.436 sec)
# INFO:tensorflow:global_step/sec: 237.659
# INFO:tensorflow:loss = 5847.152, step = 28500 (0.425 sec)
# INFO:tensorflow:global_step/sec: 230.111
# INFO:tensorflow:loss = 1131.1954, step = 28600 (0.432 sec)
# INFO:tensorflow:global_step/sec: 233.343
# INFO:tensorflow:loss = 2440.453, step = 28700 (0.429 sec)
# INFO:tensorflow:global_step/sec: 226.886
# INFO:tensorflow:loss = 4479.247, step = 28800 (0.442 sec)
# INFO:tensorflow:global_step/sec: 231.871
# INFO:tensorflow:loss = 4231.9023, step = 28900 (0.430 sec)
# INFO:tensorflow:global_step/sec: 233.151
# INFO:tensorflow:loss = 2985.014, step = 29000 (0.428 sec)
# INFO:tensorflow:global_step/sec: 228.886
# INFO:tensorflow:loss = 7815.5776, step = 29100 (0.438 sec)
# INFO:tensorflow:global_step/sec: 232.793
# INFO:tensorflow:loss = 3087.1099, step = 29200 (0.428 sec)
# INFO:tensorflow:global_step/sec: 228.001
# INFO:tensorflow:loss = 3574.7998, step = 29300 (0.444 sec)
# INFO:tensorflow:global_step/sec: 232.688
# INFO:tensorflow:loss = 2284.321, step = 29400 (0.428 sec)
# INFO:tensorflow:global_step/sec: 233.499
# INFO:tensorflow:loss = 3976.6926, step = 29500 (0.427 sec)
# INFO:tensorflow:global_step/sec: 230.142
# INFO:tensorflow:loss = 2576.2913, step = 29600 (0.436 sec)
# INFO:tensorflow:global_step/sec: 231.446
# INFO:tensorflow:loss = 2798.935, step = 29700 (0.433 sec)
# INFO:tensorflow:global_step/sec: 226.64
# INFO:tensorflow:loss = 1108.3955, step = 29800 (0.440 sec)
# INFO:tensorflow:global_step/sec: 235.793
# INFO:tensorflow:loss = 1011.7885, step = 29900 (0.424 sec)
# INFO:tensorflow:global_step/sec: 235.607
# INFO:tensorflow:loss = 2684.9084, step = 30000 (0.422 sec)
# INFO:tensorflow:global_step/sec: 235.338
# INFO:tensorflow:loss = 3200.4314, step = 30100 (0.425 sec)
# INFO:tensorflow:global_step/sec: 234.869
# INFO:tensorflow:loss = 1026.1317, step = 30200 (0.428 sec)
# INFO:tensorflow:global_step/sec: 233.941
# INFO:tensorflow:loss = 1353.895, step = 30300 (0.428 sec)
# INFO:tensorflow:global_step/sec: 236.059
# INFO:tensorflow:loss = 2346.673, step = 30400 (0.421 sec)
# INFO:tensorflow:global_step/sec: 227.843
# INFO:tensorflow:loss = 1572.4541, step = 30500 (0.439 sec)
# INFO:tensorflow:global_step/sec: 234.911
# INFO:tensorflow:loss = 3440.4482, step = 30600 (0.424 sec)
# INFO:tensorflow:global_step/sec: 233.461
# INFO:tensorflow:loss = 6926.792, step = 30700 (0.430 sec)
# INFO:tensorflow:global_step/sec: 241.917
# INFO:tensorflow:loss = 4039.412, step = 30800 (0.416 sec)
# INFO:tensorflow:global_step/sec: 235.36
# INFO:tensorflow:loss = 2440.3765, step = 30900 (0.422 sec)
# INFO:tensorflow:global_step/sec: 235.396
# INFO:tensorflow:loss = 1755.8792, step = 31000 (0.427 sec)
# INFO:tensorflow:global_step/sec: 235.754
# INFO:tensorflow:loss = 4797.4146, step = 31100 (0.425 sec)
# INFO:tensorflow:global_step/sec: 228.531
# INFO:tensorflow:loss = 1403.8333, step = 31200 (0.437 sec)
# INFO:tensorflow:global_step/sec: 238.91
# INFO:tensorflow:loss = 8703.465, step = 31300 (0.419 sec)
# INFO:tensorflow:global_step/sec: 236.303
# INFO:tensorflow:loss = 1156.1818, step = 31400 (0.422 sec)
# INFO:tensorflow:global_step/sec: 228.927
# INFO:tensorflow:loss = 2060.3335, step = 31500 (0.439 sec)
# INFO:tensorflow:global_step/sec: 236.126
# INFO:tensorflow:loss = 4043.8718, step = 31600 (0.423 sec)
# INFO:tensorflow:global_step/sec: 230.791
# INFO:tensorflow:loss = 2739.6504, step = 31700 (0.431 sec)
# INFO:tensorflow:global_step/sec: 233.765
# INFO:tensorflow:loss = 3226.6785, step = 31800 (0.431 sec)
# INFO:tensorflow:global_step/sec: 226.814
# INFO:tensorflow:loss = 1167.3717, step = 31900 (0.440 sec)
# INFO:tensorflow:global_step/sec: 233.763
# INFO:tensorflow:loss = 1696.62, step = 32000 (0.428 sec)
# INFO:tensorflow:global_step/sec: 234.299
# INFO:tensorflow:loss = 1047.1033, step = 32100 (0.429 sec)
# INFO:tensorflow:global_step/sec: 229.376
# INFO:tensorflow:loss = 2408.1084, step = 32200 (0.433 sec)
# INFO:tensorflow:global_step/sec: 237.206
# ...
# INFO:tensorflow:loss = 2015.6526, step = 522000 (0.414 sec)
# INFO:tensorflow:global_step/sec: 232.027
# INFO:tensorflow:loss = 6687.998, step = 522100 (0.430 sec)
# INFO:tensorflow:global_step/sec: 229.992
# INFO:tensorflow:loss = 2674.9814, step = 522200 (0.435 sec)
# INFO:tensorflow:global_step/sec: 235.022
# INFO:tensorflow:loss = 1649.877, step = 522300 (0.425 sec)
# INFO:tensorflow:global_step/sec: 232.214
# INFO:tensorflow:loss = 1346.3218, step = 522400 (0.428 sec)
# INFO:tensorflow:global_step/sec: 237.461
# INFO:tensorflow:loss = 738.6515, step = 522500 (0.423 sec)
# INFO:tensorflow:global_step/sec: 232.263
# INFO:tensorflow:loss = 1466.713, step = 522600 (0.432 sec)
# INFO:tensorflow:global_step/sec: 238.036
# INFO:tensorflow:loss = 1764.2262, step = 522700 (0.417 sec)
# INFO:tensorflow:global_step/sec: 239.212
# INFO:tensorflow:loss = 1343.1514, step = 522800 (0.418 sec)
# INFO:tensorflow:global_step/sec: 235.815
# INFO:tensorflow:loss = 2256.4097, step = 522900 (0.424 sec)
# INFO:tensorflow:global_step/sec: 234.966
# INFO:tensorflow:loss = 3029.0723, step = 523000 (0.428 sec)
# INFO:tensorflow:global_step/sec: 231.847
# INFO:tensorflow:loss = 4834.016, step = 523100 (0.431 sec)
# INFO:tensorflow:global_step/sec: 237.266
# INFO:tensorflow:loss = 1680.5813, step = 523200 (0.423 sec)
# INFO:tensorflow:global_step/sec: 241.325
# INFO:tensorflow:loss = 2866.3098, step = 523300 (0.412 sec)
# INFO:tensorflow:global_step/sec: 229.695
# INFO:tensorflow:loss = 1328.3187, step = 523400 (0.437 sec)
# INFO:tensorflow:global_step/sec: 243.182
# INFO:tensorflow:loss = 2091.3555, step = 523500 (0.411 sec)
# INFO:tensorflow:global_step/sec: 232.031
# INFO:tensorflow:loss = 1901.6353, step = 523600 (0.431 sec)
# INFO:tensorflow:global_step/sec: 238.793
# INFO:tensorflow:loss = 3582.3289, step = 523700 (0.416 sec)
# INFO:tensorflow:global_step/sec: 244.364
# INFO:tensorflow:loss = 1038.7002, step = 523800 (0.411 sec)
# INFO:tensorflow:global_step/sec: 233.359
# INFO:tensorflow:loss = 888.59705, step = 523900 (0.426 sec)
# INFO:tensorflow:global_step/sec: 241.688
# INFO:tensorflow:loss = 1354.5947, step = 524000 (0.418 sec)
# INFO:tensorflow:global_step/sec: 225.4
# INFO:tensorflow:loss = 6565.9404, step = 524100 (0.441 sec)
# INFO:tensorflow:global_step/sec: 229.562
# INFO:tensorflow:loss = 6824.657, step = 524200 (0.438 sec)
# INFO:tensorflow:global_step/sec: 222.4
# INFO:tensorflow:loss = 3168.5728, step = 524300 (0.448 sec)
# INFO:tensorflow:Saving checkpoints for 524400 into model_dir/model.ckpt.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-12T22:20:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-524400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-12-22:21:03
# INFO:tensorflow:Saving dict for global step 524400: average_loss = 25.215672, global_step = 524400, label/mean = 11.332427, loss = 3227.4744, prediction/mean = 11.252001, rmse = 5.0215206
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 524400: model_dir/model.ckpt-524400
# INFO:tensorflow:Loss for final step: 640.686.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-524400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 524400 into model_dir/model.ckpt.
# INFO:tensorflow:loss = 1434.2074, step = 524400
# INFO:tensorflow:global_step/sec: 199.742
# INFO:tensorflow:loss = 1497.1625, step = 524500 (0.504 sec)
# INFO:tensorflow:global_step/sec: 235.811
# INFO:tensorflow:loss = 2000.51, step = 524600 (0.425 sec)
# INFO:tensorflow:global_step/sec: 242.129
# INFO:tensorflow:loss = 3519.8628, step = 524700 (0.414 sec)
# INFO:tensorflow:global_step/sec: 236.983
# INFO:tensorflow:loss = 1683.849, step = 524800 (0.431 sec)
# INFO:tensorflow:global_step/sec: 232.239
# INFO:tensorflow:loss = 1352.5177, step = 524900 (0.418 sec)
# INFO:tensorflow:global_step/sec: 239.475
# INFO:tensorflow:loss = 3352.555, step = 525000 (0.418 sec)
# INFO:tensorflow:global_step/sec: 237.781
# INFO:tensorflow:loss = 2322.0706, step = 525100 (0.422 sec)
# INFO:tensorflow:global_step/sec: 238.443
# INFO:tensorflow:loss = 1286.9841, step = 525200 (0.417 sec)
# INFO:tensorflow:global_step/sec: 235.187
# INFO:tensorflow:loss = 3868.7703, step = 525300 (0.426 sec)
# INFO:tensorflow:global_step/sec: 240.321
# INFO:tensorflow:loss = 2538.0771, step = 525400 (0.417 sec)
# INFO:tensorflow:global_step/sec: 238.149
# INFO:tensorflow:loss = 2257.495, step = 525500 (0.422 sec)
# INFO:tensorflow:global_step/sec: 235.878
# INFO:tensorflow:loss = 3525.2622, step = 525600 (0.424 sec)
# INFO:tensorflow:global_step/sec: 240.07
# INFO:tensorflow:loss = 890.3867, step = 525700 (0.416 sec)
# INFO:tensorflow:global_step/sec: 232.683
# INFO:tensorflow:loss = 1503.1584, step = 525800 (0.429 sec)
# INFO:tensorflow:global_step/sec: 237.583
# INFO:tensorflow:loss = 2505.4893, step = 525900 (0.420 sec)
# INFO:tensorflow:global_step/sec: 238.978
# INFO:tensorflow:loss = 3991.6428, step = 526000 (0.420 sec)
# INFO:tensorflow:global_step/sec: 235.875
# INFO:tensorflow:loss = 1526.5332, step = 526100 (0.425 sec)
# INFO:tensorflow:global_step/sec: 239.909
# INFO:tensorflow:loss = 2949.807, step = 526200 (0.416 sec)
# INFO:tensorflow:global_step/sec: 226.78
# INFO:tensorflow:loss = 976.2927, step = 526300 (0.442 sec)
# INFO:tensorflow:global_step/sec: 240.218
# INFO:tensorflow:loss = 7482.698, step = 526400 (0.413 sec)
# INFO:tensorflow:global_step/sec: 240.294
# INFO:tensorflow:loss = 909.10254, step = 526500 (0.415 sec)
# INFO:tensorflow:global_step/sec: 232.053
# INFO:tensorflow:loss = 1407.4515, step = 526600 (0.434 sec)
# INFO:tensorflow:global_step/sec: 237.236
# INFO:tensorflow:loss = 791.1422, step = 526700 (0.422 sec)
# INFO:tensorflow:global_step/sec: 236.977
# INFO:tensorflow:loss = 1043.0955, step = 526800 (0.421 sec)
# INFO:tensorflow:global_step/sec: 244.029
# INFO:tensorflow:loss = 1167.4694, step = 526900 (0.410 sec)
# INFO:tensorflow:global_step/sec: 235.778
# INFO:tensorflow:loss = 1320.31, step = 527000 (0.427 sec)
# INFO:tensorflow:global_step/sec: 232.491
# INFO:tensorflow:loss = 1029.9408, step = 527100 (0.427 sec)
# INFO:tensorflow:global_step/sec: 237.368
# INFO:tensorflow:loss = 905.44165, step = 527200 (0.419 sec)
# INFO:tensorflow:global_step/sec: 236.333
# INFO:tensorflow:loss = 910.4396, step = 527300 (0.426 sec)
# INFO:tensorflow:global_step/sec: 241.994
# INFO:tensorflow:loss = 9964.531, step = 527400 (0.414 sec)
# INFO:tensorflow:global_step/sec: 234.097
# INFO:tensorflow:loss = 2931.386, step = 527500 (0.425 sec)
# INFO:tensorflow:global_step/sec: 240.983
# INFO:tensorflow:loss = 11263.139, step = 527600 (0.415 sec)
# INFO:tensorflow:global_step/sec: 240.042
# INFO:tensorflow:loss = 3981.5925, step = 527700 (0.419 sec)
# INFO:tensorflow:global_step/sec: 231.569
# INFO:tensorflow:loss = 1103.042, step = 527800 (0.431 sec)
# INFO:tensorflow:global_step/sec: 235.12
# INFO:tensorflow:loss = 1624.4822, step = 527900 (0.427 sec)
# INFO:tensorflow:global_step/sec: 232.196
# INFO:tensorflow:loss = 1258.9187, step = 528000 (0.425 sec)
# INFO:tensorflow:global_step/sec: 242.254
# INFO:tensorflow:loss = 2976.4026, step = 528100 (0.417 sec)
# INFO:tensorflow:global_step/sec: 238.104
# INFO:tensorflow:loss = 1612.6538, step = 528200 (0.420 sec)
# INFO:tensorflow:global_step/sec: 226.326
# INFO:tensorflow:loss = 1547.0, step = 528300 (0.443 sec)
# INFO:tensorflow:global_step/sec: 233.685
# INFO:tensorflow:loss = 3252.896, step = 528400 (0.426 sec)
# INFO:tensorflow:global_step/sec: 228.141
# INFO:tensorflow:loss = 1509.6187, step = 528500 (0.437 sec)
# INFO:tensorflow:global_step/sec: 239.991
# INFO:tensorflow:loss = 2709.2424, step = 528600 (0.415 sec)
# INFO:tensorflow:global_step/sec: 232.863
# INFO:tensorflow:loss = 4638.706, step = 528700 (0.433 sec)
# INFO:tensorflow:global_step/sec: 237.006
# INFO:tensorflow:loss = 2746.6272, step = 528800 (0.421 sec)
# INFO:tensorflow:global_step/sec: 239.896
# INFO:tensorflow:loss = 1137.901, step = 528900 (0.413 sec)
# INFO:tensorflow:global_step/sec: 232.994
# INFO:tensorflow:loss = 6221.1797, step = 529000 (0.433 sec)
# INFO:tensorflow:global_step/sec: 239.52
# INFO:tensorflow:loss = 2214.0015, step = 529100 (0.415 sec)
# INFO:tensorflow:global_step/sec: 233.601
# INFO:tensorflow:loss = 5513.011, step = 529200 (0.428 sec)
# INFO:tensorflow:global_step/sec: 245.967
# INFO:tensorflow:loss = 1521.454, step = 529300 (0.406 sec)
# INFO:tensorflow:global_step/sec: 240.603
# INFO:tensorflow:loss = 16885.703, step = 529400 (0.419 sec)
# INFO:tensorflow:global_step/sec: 230.786
# INFO:tensorflow:loss = 2221.4707, step = 529500 (0.434 sec)
# INFO:tensorflow:global_step/sec: 241.781
# INFO:tensorflow:loss = 1665.8602, step = 529600 (0.410 sec)
# INFO:tensorflow:global_step/sec: 230.114
# INFO:tensorflow:loss = 2435.439, step = 529700 (0.434 sec)
# INFO:tensorflow:global_step/sec: 238.591
# INFO:tensorflow:loss = 1875.4464, step = 529800 (0.420 sec)
# INFO:tensorflow:global_step/sec: 233.791
# INFO:tensorflow:loss = 8714.193, step = 529900 (0.428 sec)
# INFO:tensorflow:global_step/sec: 232.655
# INFO:tensorflow:loss = 6576.4995, step = 530000 (0.429 sec)
# INFO:tensorflow:global_step/sec: 241.482
# INFO:tensorflow:loss = 1646.1218, step = 530100 (0.414 sec)
# INFO:tensorflow:global_step/sec: 235.06
# INFO:tensorflow:loss = 161654.88, step = 530200 (0.426 sec)
# INFO:tensorflow:global_step/sec: 236.857
# INFO:tensorflow:loss = 2830.9038, step = 530300 (0.422 sec)
# INFO:tensorflow:global_step/sec: 238.488
# INFO:tensorflow:loss = 1442.9558, step = 530400 (0.422 sec)
# INFO:tensorflow:global_step/sec: 233.38
# INFO:tensorflow:loss = 7896.539, step = 530500 (0.425 sec)
# INFO:tensorflow:global_step/sec: 239.316
# INFO:tensorflow:loss = 2630.6174, step = 530600 (0.421 sec)
# INFO:tensorflow:global_step/sec: 233.061
# INFO:tensorflow:loss = 1158.1904, step = 530700 (0.429 sec)
# INFO:tensorflow:global_step/sec: 237.398
# INFO:tensorflow:loss = 3093.9236, step = 530800 (0.422 sec)
# INFO:tensorflow:global_step/sec: 230.391
# INFO:tensorflow:loss = 3072.716, step = 530900 (0.433 sec)
# INFO:tensorflow:global_step/sec: 237.315
# INFO:tensorflow:loss = 840.0144, step = 531000 (0.419 sec)
# INFO:tensorflow:global_step/sec: 236.866
# INFO:tensorflow:loss = 1020.7847, step = 531100 (0.425 sec)
# INFO:tensorflow:global_step/sec: 228.62
# INFO:tensorflow:loss = 1638.1884, step = 531200 (0.437 sec)
# INFO:tensorflow:Saving checkpoints for 531300 into model_dir/model.ckpt.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-12T22:21:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-531300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-12-22:21:48
# INFO:tensorflow:Saving dict for global step 531300: average_loss = 25.249739, global_step = 531300, label/mean = 11.332449, loss = 3231.835, prediction/mean = 11.521657, rmse = 5.024912
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 531300: model_dir/model.ckpt-531300
# INFO:tensorflow:Loss for final step: 370.52106.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# {'fare': <tf.Tensor 'IteratorGetNext:5' shape=(?, 1) dtype=float32>, 'distance': <tf.Tensor 'IteratorGetNext:2' shape=(?, 1) dtype=float32>, 'day_of_year': <tf.Tensor 'IteratorGetNext:1' shape=(?, 1) dtype=float32>, 'day_of_week': <tf.Tensor 'IteratorGetNext:0' shape=(?, 1) dtype=float32>, 'dropoff_longitude': <tf.Tensor 'IteratorGetNext:4' shape=(?, 1) dtype=float32>, 'pickup_longitude': <tf.Tensor 'IteratorGetNext:8' shape=(?, 1) dtype=float32>, 'year': <tf.Tensor 'IteratorGetNext:9' shape=(?, 1) dtype=float32>, 'minutes_since_midnight': <tf.Tensor 'IteratorGetNext:6' shape=(?, 1) dtype=float32>, 'pickup_latitude': <tf.Tensor 'IteratorGetNext:7' shape=(?, 1) dtype=float32>, 'dropoff_latitude': <tf.Tensor 'IteratorGetNext:3' shape=(?, 1) dtype=float32>}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_dir/model.ckpt-531300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 531300 into model_dir/model.ckpt.
# INFO:tensorflow:loss = 1475.3746, step = 531300
# INFO:tensorflow:global_step/sec: 202.693
# INFO:tensorflow:loss = 2782.2288, step = 531400 (0.495 sec)
# INFO:tensorflow:global_step/sec: 235.423
# INFO:tensorflow:loss = 1072.2909, step = 531500 (0.428 sec)
# INFO:tensorflow:global_step/sec: 240.894
# INFO:tensorflow:loss = 9878.296, step = 531600 (0.415 sec)

# %%
import itertools
import math

testdf = pd.read_csv('test.csv')

for index, row in testdf.iterrows():
  fare_amount = row['fare_amount']
  pickup_datetime = row['pickup_datetime']
  pickup_longitude = row['pickup_longitude']
  pickup_latitude = row['pickup_latitude']
  dropoff_longitude = row['dropoff_longitude']
  dropoff_latitude = row['dropoff_latitude']
  if math.isnan(dropoff_longitude) or math.isnan(dropoff_latitude) or math.isnan(pickup_longitude) or math.isnan(pickup_latitude) or pickup_datetime==False or math.isnan(fare_amount) or pickup_longitude==0:
    complete = False
  dt = parser.parse(pickup_datetime)
  year = dt.year
  day_of_year = dt.timetuple().tm_yday
  day_of_week = dt.weekday()
  minutes_since_midnight = (dt.hour * 60) + dt.minute
  distance= 1000*((pickup_latitude-dropoff_latitude)**2 + (pickup_longitude-dropoff_longitude)**2)**.5
  features = {
      "pickup_longitude": tf.train.Feature(float_list = tf.train.FloatList(value=[pickup_longitude])),
      "pickup_latitude": tf.train.Feature(float_list = tf.train.FloatList(value=[pickup_latitude])),
      "fare": tf.train.Feature(float_list = tf.train.FloatList(value=[fare_amount])),
      "distance": tf.train.Feature(float_list = tf.train.FloatList(value=[distance])),
      "year": tf.train.Feature(float_list = tf.train.FloatList(value=[year])),
      "day_of_year": tf.train.Feature(float_list = tf.train.FloatList(value=[day_of_year])),
      "day_of_week": tf.train.Feature(float_list = tf.train.FloatList(value=[day_of_week])),
      "minutes_since_midnight": tf.train.Feature(float_list = tf.train.FloatList(value=[minutes_since_midnight])),
      "dropoff_longitude": tf.train.Feature(float_list = tf.train.FloatList(value=[dropoff_longitude])),
      "dropoff_latitude": tf.train.Feature(float_list = tf.train.FloatList(value=[dropoff_latitude])),
  }

testdf['YearBuilt'] = (testdf['YearBuilt'] - 1990) / 10.0
testdf['LotArea'] = testdf['LotArea'] / 1000.
testdf['GrLivArea'] = testdf['GrLivArea'] / 1000.

for index, row in testdf.iterrows():
  OverallQual = row['OverallQual']
  OverallCond = row['OverallCond']
  YearBuilt = row['YearBuilt']
  FullBath = row['FullBath']
  BedroomAbvGr = row['BedroomAbvGr']
  HalfBath = row['HalfBath']
  LotArea = row['LotArea']
  GrLivArea = row['GrLivArea']
  Neighborhood = row['Neighborhood']
  if math.isnan(OverallQual):
    row['OverallQual'] = 5
  if math.isnan(OverallCond):
    row['OverallCond'] = 5
  if math.isnan(YearBuilt):
    row['YearBuilt'] = 0
  if math.isnan(FullBath):
    row['FullBath'] = 2
  if math.isnan(BedroomAbvGr):
    row['BedroomAbvGr'] = 2
    
def eval_input_fn1():
  eval_dataset1 = tf.data.Dataset.from_tensor_slices((dict(testdf)))
  #eval_dataset1 = eval_dataset1.shuffle(batch_size).repeat().batch(batch_size)
  eval_dataset1 = eval_dataset1.batch(len(testdf))
  return eval_dataset1

def test_input_fn(df):
  x = {
      'pickup_longitude':tf.constant(
      df['pickup_longitude'].values,
          shape = [df['pickup_longitude'].size,1],
          dtype=tf.float32),
      'pickup_latitude':tf.constant(
      df['pickup_latitude'].values,
          shape = [df['pickup_latitude'].size,1],
          dtype=tf.float32),
      'YearBuilt':tf.constant(
      df['YearBuilt'].values,
          shape = [df['YearBuilt'].size,1],
          dtype=tf.float32),
      'FullBath':tf.constant(
      df['FullBath'].values,
          shape = [df['FullBath'].size,1],
          dtype=tf.float32),
      'BedroomAbvGr':tf.constant(
      df['BedroomAbvGr'].values,
          shape = [df['BedroomAbvGr'].size,1],
          dtype=tf.float32),
      'HalfBath':tf.constant(
      df['HalfBath'].values,
          shape = [df['HalfBath'].size,1],
          dtype=tf.float32),
      'LotArea':tf.constant(
      df['LotArea'].values,
          shape = [df['LotArea'].size,1],
          dtype=tf.float32),
      'GrLivArea':tf.constant(
      df['GrLivArea'].values,
          shape = [df['GrLivArea'].size,1],
          dtype=tf.float32),
      'Neighborhood':tf.constant(
      df['Neighborhood'].values,
          shape = [df['Neighborhood'].size,1],
          dtype=tf.string)
  }
  return x

def test_fn_predictions():
  return test_input_fn(testdf)

# For int features:
# 'name': tf.train.Feature(int64_list = tf.train.Int64List(value = ...))
# For float features:
# 'name': tf.train.Feature(float_list = tf.train.FloatList(value = ...))

predictions_generator = regressor.predict(
    input_fn=test_fn_predictions,
    yield_single_examples=True)

iter = itertools.islice(predictions_generator, 1459)

predictions = [y['predictions'][0] for y in iter]

print len(predictions), "predictions:"
print predictions

predictions = [math.exp(i) for i in predictions]
submission = [["Id", "SalePrice"]]
for i in range(1459):
  submission.append([testdf['Id'][i], predictions[i]])
print submission

# %%
variable_names = regressor.get_variable_names()
print "variable names: "
for var_name in variable_names:
  values = regressor.get_variable_value(var_name)
  print var_name, values

# %%
values = regressor.get_variable_value("")

# %% [markdown]
# # Show tensorboard analytics on model training

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
# kill currently running tensorboard instance, if any
#!ps wx
# !kill -9 1383

# %%
LOG_DIR = './model_dir3'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
#!ls -l model_dir.tar
#!gzip model_dir.tar
# !ls -l model_dir.tar.gz

# %%
def eval_input_fn1():
  eval_dataset1 = tf.data.Dataset.from_tensor_slices((dict(features_df1)))
  #eval_dataset1 = eval_dataset1.shuffle(batch_size).repeat().batch(batch_size)
  eval_dataset1 = eval_dataset1.batch(len(features_df1))
  return eval_dataset1

# %%
import tensorflow as tf
import pandas as pd
from dateutil import parser
import datetime
from datetime import date
import math

def get_test_features(row):
  complete = True
  pickup_datetime = row['pickup_datetime']
  pickup_longitude = row['pickup_longitude']
  pickup_latitude = row['pickup_latitude']
  dropoff_longitude = row['dropoff_longitude']
  dropoff_latitude = row['dropoff_latitude']
  dt = parser.parse(pickup_datetime)
  year = dt.year
  day_of_year = dt.timetuple().tm_yday
  day_of_week = dt.weekday()
  minutes_since_midnight = (dt.hour * 60) + dt.minute
  distance= 1000*((pickup_latitude-dropoff_latitude)**2 + (pickup_longitude-dropoff_longitude)**2)**.5
  features = {
      "pickup_longitude": tf.train.Feature(float_list = tf.train.FloatList(value=[pickup_longitude])),
      "pickup_latitude": tf.train.Feature(float_list = tf.train.FloatList(value=[pickup_latitude])),
      "distance": tf.train.Feature(float_list = tf.train.FloatList(value=[distance])),
      "year": tf.train.Feature(float_list = tf.train.FloatList(value=[year])),
      "day_of_year": tf.train.Feature(float_list = tf.train.FloatList(value=[day_of_year])),
      "day_of_week": tf.train.Feature(float_list = tf.train.FloatList(value=[day_of_week])),
      "minutes_since_midnight": tf.train.Feature(float_list = tf.train.FloatList(value=[minutes_since_midnight])),
      "dropoff_longitude": tf.train.Feature(float_list = tf.train.FloatList(value=[dropoff_longitude])),
      "dropoff_latitude": tf.train.Feature(float_list = tf.train.FloatList(value=[dropoff_latitude])),
  }
  return features

reader = pd.read_csv('test.csv')
print reader


tfr_file = ("test_examples.tfr")
print "generating TFRecord file " + tfr_file
test_writer = tf.python_io.TFRecordWriter(tfr_file)  

# For int features:
# 'name': tf.train.Feature(int64_list = tf.train.Int64List(value = ...))
# For float features:
# 'name': tf.train.Feature(float_list = tf.train.FloatList(value = ...))


  


for index, row in reader.iterrows():
  feature = get_test_features(row)
  
  example = tf.train.Example(
      features=tf.train.Features(feature=feature))
  test_writer.write(example.SerializeToString())

test_writer.close()

# %%
# !ls
